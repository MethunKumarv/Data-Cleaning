# %% [markdown]
# <center>
#     <h1>Data Cleaning Process</h1>
#     <a href="https://www.kaggle.com/datasets/shaikhjaveriya/dirtydata-csv">Dataset link</a>
# </center>

# %%
import pandas as pd

# %% [markdown]
# ### Load the dataset

# %%
file_path = "C:\\Users\\METHUNKUMAR\\Downloads\\dirtydata.csv"
df = pd.read_csv(file_path)

# %%
print("Original Dataframe")
df
# Out:
# Original Dataframe
#     Duration          Date   Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.00       130     409.1
# 1         60  '2020/12/02'  117.00       145     479.0
# 2         60  '2020/12/03'  103.00       135     340.0
# 3         45  '2020/12/04'  109.00       175     282.4
# 4         45  '2020/12/05'  117.00       148     406.0
# 5         60  '2020/12/06'  102.00       127     300.0
# 6         60  '2020/12/07'   44.22       136     374.0
# 7        450  '2020/12/08'  104.00       134     253.3
# 8         30  '2020/12/09'  109.00       133     195.1
# 9         60  '2020/12/10'   98.00       124     269.0
# 10        60  '2020/12/11'  103.00       147     329.3
# 11        60  '2020/12/12'  100.00       120     250.7
# 12        60  '2020/12/12'  100.00       120     250.7
# 13        60  '2020/12/13'  106.00       128     345.3
# 14        60  '2020/12/14'  104.00       132     379.3
# 15        60  '2020/12/15'   98.00       123     275.0
# 16        60  '2020/12/16'   98.00       120     215.2
# 17        60  '2020/12/17'  100.00       120     300.0
# 18        45  '2020/12/18'   90.00       112       NaN
# 19        60   2020/12/33'  103.00       123     323.0
# 20        45  '2020/12/20'   97.00       125     243.0
# 21        60  '2020/12/21'  108.00       131     364.2
# 22        45           NaN  100.00       119     282.0
# 23        60  '2020/12/23'  130.00       101     300.0
# 24        45   2020/13/24'  105.00       132     246.0
# 25        60   2020/12/25'  102.00       126     334.5
# 26        60           NaN  100.00       120     250.0
# 27        60  '2020/12/27'   92.00       118     241.0
# 28        60  '2020/12/28'  103.00       132       NaN
# 29        60  '2020/12/29'  100.00       132     280.0
# 30        60  '2020/12/30'  102.00       129     380.3
# 31        60  '2020/12/31'   92.00       115     243.0

# %% [markdown]
# ### Step 1: Display the summary of the dataset

# %%
print("Initial Dataset Summary:")
df.info()
# Out:
# Initial Dataset Summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      30 non-null     object
#  2   Pulse     32 non-null     float64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1.4+ KB

# %% [markdown]
# ### Step 2: Check for missing values

# %%
missing_values = df.isnull().sum()
print("\nMissing Values")
print(missing_values)
# Out:
# Missing Values
# Duration    0
# Date        2
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %% [markdown]
# ### Step 3: Handling missing values

# %% [markdown]
# #### Fill numeric missing values with mean

# %%
for column in df.select_dtypes(include=['float64', 'int64']).columns:
    df.fillna({column: df[column].mean()}, inplace=True)

# %% [markdown]
# #### Fill missing values in categorical columns with the mode

# %%
for column in df.select_dtypes(include=['object']).columns:
    df.fillna({column: df[column].mode()[0]}, inplace=True)

# %% [markdown]
# ### Step 4: Removing duplicates

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Step 5: Fixing data types

# %% [markdown]
# #### Convert 'date' column to datetime if present

# %%
if 'date' in df.columns:
    df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %% [markdown]
# ### Step 6: Standardizing text data

# %%
df = df.map(lambda x: x.strip().lower() if isinstance(x, str) else x)

# %% [markdown]
# ### Step 7: Remove invalid values or outliers

# %%
df = df[(df['Duration'] >= 0) & (df['Duration'] <= 60)]

# %% [markdown]
# ### Step 8: Check for dataset after cleaning

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  30 non-null     int64
#  1   Date      30 non-null     object
#  2   Pulse     30 non-null     float64
#  3   Maxpulse  30 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1.4+ KB
#     Duration          Date   Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.00       130    409.10
# 1         60  '2020/12/02'  117.00       145    479.00
# 2         60  '2020/12/03'  103.00       135    340.00
# 3         45  '2020/12/04'  109.00       175    282.40
# 4         45  '2020/12/05'  117.00       148    406.00
# 5         60  '2020/12/06'  102.00       127    300.00
# 6         60  '2020/12/07'   44.22       136    374.00
# 8         30  '2020/12/09'  109.00       133    195.10
# 9         60  '2020/12/10'   98.00       124    269.00
# 10        60  '2020/12/11'  103.00       147    329.30
# 11        60  '2020/12/12'  100.00       120    250.70
# 13        60  '2020/12/13'  106.00       128    345.30
# 14        60  '2020/12/14'  104.00       132    379.30
# 15        60  '2020/12/15'   98.00       123    275.00
# 16        60  '2020/12/16'   98.00       120    215.20
# 17        60  '2020/12/17'  100.00       120    300.00
# 18        45  '2020/12/18'   90.00       112    304.68
# 19        60   2020/12/33'  103.00       123    323.00
# 20        45  '2020/12/20'   97.00       125    243.00
# 21        60  '2020/12/21'  108.00       131    364.20
# 22        45  '2020/12/12'  100.00       119    282.00
# 23        60  '2020/12/23'  130.00       101    300.00
# 24        45   2020/13/24'  105.00       132    246.00
# 25        60   2020/12/25'  102.00       126    334.50
# 26        60  '2020/12/12'  100.00       120    250.00
# 27        60  '2020/12/27'   92.00       118    241.00
# 28        60  '2020/12/28'  103.00       132    304.68
# 29        60  '2020/12/29'  100.00       132    280.00
# 30        60  '2020/12/30'  102.00       129    380.30
# 31        60  '2020/12/31'   92.00       115    243.00

# %% [markdown]
# ### Step 9: Save the cleaned data to a new CSV file

# %%
cleaned_file_path = "C:\\Users\\METHUNKUMAR\\Downloads\\cleaned_data.csv"
df.to_csv(cleaned_file_path, index=False, header=True)

# %% [markdown]
# ### Step 10: Check cleaned_data.csv file

# %%
cleaned_df = pd.read_csv("C:\\Users\\METHUNKUMAR\\Downloads\\cleaned_data.csv")
cleaned_df.info()
cleaned_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  30 non-null     int64
#  1   Date      30 non-null     object
#  2   Pulse     30 non-null     float64
#  3   Maxpulse  30 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1.3+ KB
#     Duration          Date   Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.00       130    409.10
# 1         60  '2020/12/02'  117.00       145    479.00
# 2         60  '2020/12/03'  103.00       135    340.00
# 3         45  '2020/12/04'  109.00       175    282.40
# 4         45  '2020/12/05'  117.00       148    406.00
# 5         60  '2020/12/06'  102.00       127    300.00
# 6         60  '2020/12/07'   44.22       136    374.00
# 7         30  '2020/12/09'  109.00       133    195.10
# 8         60  '2020/12/10'   98.00       124    269.00
# 9         60  '2020/12/11'  103.00       147    329.30
# 10        60  '2020/12/12'  100.00       120    250.70
# 11        60  '2020/12/13'  106.00       128    345.30
# 12        60  '2020/12/14'  104.00       132    379.30
# 13        60  '2020/12/15'   98.00       123    275.00
# 14        60  '2020/12/16'   98.00       120    215.20
# 15        60  '2020/12/17'  100.00       120    300.00
# 16        45  '2020/12/18'   90.00       112    304.68
# 17        60   2020/12/33'  103.00       123    323.00
# 18        45  '2020/12/20'   97.00       125    243.00
# 19        60  '2020/12/21'  108.00       131    364.20
# 20        45  '2020/12/12'  100.00       119    282.00
# 21        60  '2020/12/23'  130.00       101    300.00
# 22        45   2020/13/24'  105.00       132    246.00
# 23        60   2020/12/25'  102.00       126    334.50
# 24        60  '2020/12/12'  100.00       120    250.00
# 25        60  '2020/12/27'   92.00       118    241.00
# 26        60  '2020/12/28'  103.00       132    304.68
# 27        60  '2020/12/29'  100.00       132    280.00
# 28        60  '2020/12/30'  102.00       129    380.30
# 29        60  '2020/12/31'   92.00       115    243.00
